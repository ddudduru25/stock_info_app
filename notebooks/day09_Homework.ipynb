# %% [markdown]
# # [실습] 의사 코드를 보고, 주식 웹 앱 코드를 (생각나는 대로) 작성해보세요.
#
# 의사 코드란?
# > 자연어를 이용해 프로그래밍 언어와 유사한 형식으로 배치한 코드를 뜻한다. 용도는 미술의 스케치와 같다.
# &nbsp;
#
# ```python
# [실습 1] 각종 모듈과 라이브러리를 임포트해주세요.
# - 스트림릿(streamlit)
# - 판다스(pandas)
# - 야후 파이낸스(yfinance)
# - 데이트타임(datetime)
# - 맷플롯립(matplotlib)
# - BytesIO
#
# [실습 2] 한국 주식 종목 코드를 가져오는 함수를 작성해주세요.
# - get_stock_info() 함수
# - 이 함수는 5일차에 완성했습니다.
#
# [실습 3] yfinance에 이용할 Ticker 심볼을 반환하는 함수를 작성해주세요.
# - get_ticker_symbol() 함수
# - 이 함수는 6일차에 완성했습니다.
#
# [실습 4] 스트림릿을 이용해 웹 앱을 만들어주세요.
# - 스트림릿은 7~8일차에 배웠습니다.
# ```
#
# 막히더라도 괜찮아요. 생각나는 대로 한 번 작성해보세요.
# 이번 실습은 stock_info_app.py에 작성한 코드를 모두 지우고 새로 작성해주세요.

# %% [markdown]
# ---

# %% [markdown]
# # [실습 1] 각종 모듈과 라이브러리를 임포트하기
#
# 먼저 첫 번째 블록을 완성해볼게요.
#
# ```python
# # 힌트
# import 모듈명 as 별명
# ```

# %%
# stock_info_app.py에 코드를 작성해주세요.

# %% [markdown]
# ---

# %% [markdown]
# # [실습 2] 한국 주식 종목 코드를 가져오는 함수를 작성하기
#
# 이어서 두 번째 블록인 get_stock_info() 함수를 완성해볼게요.
#
# ```python
# # 힌트
# 헷갈리거나 기억나지 않는 부분이 있다면 5일차 실습 파일을 살펴봐주세요.
# ```

# %%
# stock_info_app.py에 코드를 작성해주세요.

#----------------------------------------
# 한국 주식 종목 코드를 가져오는 함수
#----------------------------------------
def get_stock_info(maket_type=None):
    
    
    return df

# %% [markdown]
# ---

# %% [markdown]
# # [실습 3] yfinance에 이용할 Ticker 심볼을 반환하는 함수를 작성하기
#
# 이어서 세 번째 블록인 get_ticker_symbol() 함수를 완성해볼게요.
#
# ```python
# # 힌트
# 헷갈리거나 기억나지 않는 부분이 있다면 6일차 실습 파일을 살펴봐주세요.
# ```

# %%
# stock_info_app.py에 코드를 작성해주세요.

#----------------------------------------------------
# yfinance에 이용할 Ticker 심볼을 반환하는 함수
#----------------------------------------------------
def get_ticker_symbol(company_name, maket_type):
    
    
    return ticker_symbol

# %% [markdown]
# ---

# %% [markdown]
# # [실습 4] 스트림릿을 이용해 웹 앱 만들기
#
# 마지막으로 네 번째 블록인 스트림릿을 이용해 웹 앱을 만들어볼게요.
#
# ```python
# ##### 사이드바 만들기
# # 1. text_input(), date_input()으로 주식 종목 이름, 기간을 입력 받아서 stock_name, date_range 변수에 담기
# # 2. button()으로 버튼 만들기
#
#
# ##### 버튼을 클릭하면 처리해야 하는 일
# # 3. get_ticker_symbol을 호출해 티커 심볼 구하기
# # 인자로 주식 종목 이름(stock_name)과 마켓 타입(kospi) 전달
#
# # 4. 야후 파이낸스로부터 Ticker 객체 가져오기
# # 인자로 ticker_symbol 전달
#
# # 5. 시작일과 종료일을 start_p, end_p 변수에 담기
# # 종료일은 date_range 변수에 담긴 값에 하루를 더해주기
#
# # 6. 시작일과 종료일을 지정해 주가 데이터 가져오기
#
#
# ##### 메인 영역에 데이터 출력하기
# # 7. 주식 데이터를 데이터 프레임 형태로 출력
# # 8. 주식 데이터를 차트 형태로 출력
# # 9. 파일 다운로드
# ```
#
# ```python
# # 힌트
# 사이드바 만들기
#  - 8일차 실습 파일을 살펴봐주세요.
#
# 버튼을 클릭하면 처리해야 하는 일
#  - 6일차 실습 파일을 살펴봐주세요.
#
# 메인 영역에 데이터 출력하기 (주식 데이터 출력하기)
#  - 7일차 실습 파일을 살펴봐주세요.
#
# 메인 영역에 데이터 출력하기 (파일 다운로드)
#  - 8일차 실습 파일을 살펴봐주세요.
# ```

# %%
# stock_info_app.py에 코드를 작성해주세요.

##############################################################################
# 1. text_input(), date_input()으로 주식 종목 이름, 기간을 입력 받아서 stock_name, date_range 변수에 담기
##############################################################################
# 여기에 코드를 작성해주세요.


##############################################################################
# 2. button()으로 버튼 만들기
##############################################################################
# 여기에 코드를 작성해주세요.

    ##############################################################################
    # 3. get_ticker_symbol을 호출해 티커 심볼 구하기
    # 인자로 주식 종목 이름(stock_name)과 마켓 타입(kospi) 전달
    ##############################################################################
    # 여기에 코드를 작성해주세요.


    ##############################################################################
    # 4. 야후 파이낸스로부터 Ticker 객체 가져오기
    # 인자로 ticker_symbol 전달
    ##############################################################################
    # 여기에 코드를 작성해주세요.


    ##############################################################################
    # 5. 시작일과 종료일을 start_p, end_p 변수에 담기
    # 종료일은 date_range 변수에 담긴 값에 하루를 더해주기
    ##############################################################################
    # 여기에 코드를 작성해주세요.


    ##############################################################################
    # 6. 시작일과 종료일을 지정해 주가 데이터 가져오기
    # 종료일은 date_range 변수에 담긴 값에 하루를 더해주기
    ##############################################################################
    # 여기에 코드를 작성해주세요.


    ##############################################################################
    # 7. 주식 데이터를 데이터 프레임 형태로 출력
    ##############################################################################
    # 여기에 코드를 작성해주세요.
    

    ##############################################################################
    # 8. 주식 데이터를 차트 형태로 출력
    ##############################################################################
    # 여기에 코드를 작성해주세요.
    
    
    ##############################################################################
    # 9. 파일 다운로드
    ##############################################################################
    # 여기에 코드를 작성해주세요.

# %% [markdown]
# ---

# %% [markdown]
# # 👏🏽👏🏽👏🏽
# # 주식 웹 앱 완성을 진심으로 축하드립니다

# %% [markdown]
# ![스크린샷 2023-01-03 오전 1.08.18.png](data:image/png;base64,...)

# %% [markdown]
# ---
